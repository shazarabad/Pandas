# %% [markdown]
# # Part 1

# %% [markdown]
# ### import pandas , import csv ,  display table, shape, info , max_col , top bottom data

# %%
import pandas as pd

# %%
df= pd.read_csv('C:/Users/sh.azarabad/Desktop/machine learning dataset/Hotel/Hotel_Reservations.csv')

# %%
df
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0       INN00001             2               0                     1
# 1       INN00002             2               0                     2
# 2       INN00003             1               0                     2
# 3       INN00004             2               0                     0
# 4       INN00005             2               0                     1
# ...          ...           ...             ...                   ...
# 36270   INN36271             3               0                     2
# 36271   INN36272             2               0                     1
# 36272   INN36273             2               0                     2
# 36273   INN36274             2               0                     0
# 36274   INN36275             2               0                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# ...

# %%
df.shape
# Out:
# (36275, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36275 entries, 0 to 36274
# Data columns (total 19 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Booking_ID                            36275 non-null  object
#  1   no_of_adults                          36275 non-null  int64
#  2   no_of_children                        36275 non-null  int64
#  3   no_of_weekend_nights                  36275 non-null  int64
#  4   no_of_week_nights                     36275 non-null  int64
#  5   type_of_meal_plan                     36275 non-null  object
#  6   required_car_parking_space            36275 non-null  int64
#  7   room_type_reserved                    36275 non-null  object
#  8   lead_time                             36275 non-null  int64
#  9   arrival_year                          36275 non-null  int64
#  10  arrival_month                         36275 non-null  int64
# ...

# %%
pd.set_option('display.max_columns',19)

# %%
df.head(10)
# Out:
#   Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0   INN00001             2               0                     1
# 1   INN00002             2               0                     2
# 2   INN00003             1               0                     2
# 3   INN00004             2               0                     0
# 4   INN00005             2               0                     1
# 5   INN00006             2               0                     0
# 6   INN00007             2               0                     1
# 7   INN00008             2               0                     1
# 8   INN00009             3               0                     0
# 9   INN00010             2               0                     0
#
#    no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                  2       Meal Plan 1                           0
# 1                  3      Not Selected                           0
# ...

# %%
df.tail(10)
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 36265   INN36266             2               0                     1
# 36266   INN36267             2               0                     2
# 36267   INN36268             2               0                     1
# 36268   INN36269             1               0                     0
# 36269   INN36270             2               2                     0
# 36270   INN36271             3               0                     2
# 36271   INN36272             2               0                     1
# 36272   INN36273             2               0                     2
# 36273   INN36274             2               0                     0
# 36274   INN36275             2               0                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 36265                  3       Meal Plan 1                           0
# ...

# %% [markdown]
# # Part2

# %% [markdown]
# ## Dictionary in python

# %%
people ={
    "fisrt" : ["shahab" , "sadegh" , "nasrin"],
    "last" : ["azarabad" , "mirzaei", "ebadpour"],
    "email" : ["yahoo" , "gmail" , "gmail"]
    
}

# %%
people['fisrt']
# Out:
# ['shahab', 'sadegh', 'nasrin']

# %% [markdown]
# # Let's set dictionary as dataframe

# %%
import pandas as pd

# %%
d_df=pd.DataFrame(people)
d_df
# Out:
#     fisrt      last  email
# 0  shahab  azarabad  yahoo
# 1  sadegh   mirzaei  gmail
# 2  nasrin  ebadpour  gmail

# %%
d_df['last']
# Out:
# 0    azarabad
# 1     mirzaei
# 2    ebadpour
# Name: last, dtype: object

# %%
d_df.email
# Out:
# 0    yahoo
# 1    gmail
# 2    gmail
# Name: email, dtype: object

# %%
d_df[['fisrt' , 'last']]
# Out:
#     fisrt      last
# 0  shahab  azarabad
# 1  sadegh   mirzaei
# 2  nasrin  ebadpour

# %%
d_df.columns
# Out:
# Index(['fisrt', 'last', 'email'], dtype='object')

# %%
d_df.iloc[2]
# Out:
# fisrt      nasrin
# last     ebadpour
# email       gmail
# Name: 2, dtype: object

# %%
d_df.iloc[[0,2],[1,2]]
# Out:
#        last  email
# 0  azarabad  yahoo
# 2  ebadpour  gmail

# %%
d_df.loc[[0,1],'fisrt']
# Out:
# 0    shahab
# 1    sadegh
# Name: fisrt, dtype: object

# %% [markdown]
# ## get back to df

# %%
df.shape
# Out:
# (36275, 19)

# %%
df
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0       INN00001             2               0                     1
# 1       INN00002             2               0                     2
# 2       INN00003             1               0                     2
# 3       INN00004             2               0                     0
# 4       INN00005             2               0                     1
# ...          ...           ...             ...                   ...
# 36270   INN36271             3               0                     2
# 36271   INN36272             2               0                     1
# 36272   INN36273             2               0                     2
# 36273   INN36274             2               0                     0
# 36274   INN36275             2               0                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# ...

# %%
df.columns
# Out:
# Index(['Booking_ID', 'no_of_adults', 'no_of_children', 'no_of_weekend_nights',
#        'no_of_week_nights', 'type_of_meal_plan', 'required_car_parking_space',
#        'room_type_reserved', 'lead_time', 'arrival_year', 'arrival_month',
#        'arrival_date', 'market_segment_type', 'repeated_guest',
#        'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled',
#        'avg_price_per_room', 'no_of_special_requests', 'booking_status'],
#       dtype='object')

# %%
df['type_of_meal_plan']
# Out:
# 0         Meal Plan 1
# 1        Not Selected
# 2         Meal Plan 1
# 3         Meal Plan 1
# 4        Not Selected
#              ...
# 36270     Meal Plan 1
# 36271     Meal Plan 1
# 36272     Meal Plan 1
# 36273    Not Selected
# 36274     Meal Plan 1
# Name: type_of_meal_plan, Length: 36275, dtype: object

# %%
df['type_of_meal_plan'].value_counts()
# Out:
# Meal Plan 1     27835
# Not Selected     5130
# Meal Plan 2      3305
# Meal Plan 3         5
# Name: type_of_meal_plan, dtype: int64

# %%
df.loc[[1,2,3],'type_of_meal_plan']
# Out:
# 1    Not Selected
# 2     Meal Plan 1
# 3     Meal Plan 1
# Name: type_of_meal_plan, dtype: object

# %%
df.loc[1:4,'type_of_meal_plan':'arrival_year']
# Out:
#   type_of_meal_plan  required_car_parking_space room_type_reserved  lead_time  \
# 1      Not Selected                           0        Room_Type 1          5
# 2       Meal Plan 1                           0        Room_Type 1          1
# 3       Meal Plan 1                           0        Room_Type 1        211
# 4      Not Selected                           0        Room_Type 1         48
#
#    arrival_year
# 1          2018
# 2          2018
# 3          2018
# 4          2018

# %% [markdown]
# # Part3

# %% [markdown]
# ## Indexes

# %%
d_df
# Out:
#     fisrt      last  email
# 0  shahab  azarabad  yahoo
# 1  sadegh   mirzaei  gmail
# 2  nasrin  ebadpour  gmail

# %%
d_df['email']
# Out:
# 0    yahoo
# 1    gmail
# 2    gmail
# Name: email, dtype: object

# %% [markdown]
# ### Let's set email as indexes

# %%
d_df.set_index('email')
# Out:
#         fisrt      last
# email
# yahoo  shahab  azarabad
# gmail  sadegh   mirzaei
# gmail  nasrin  ebadpour

# %% [markdown]
# ### main data frame has not been change , but if you want to do that use the code below

# %%
d_df2=d_df.copy()
d_df2.set_index('email' , inplace=True)
d_df2
# Out:
#         fisrt      last
# email
# yahoo  shahab  azarabad
# gmail  sadegh   mirzaei
# gmail  nasrin  ebadpour

# %%
d_df2.index
# Out:
# Index(['yahoo', 'gmail', 'gmail'], dtype='object', name='email')

# %%
d_df2.loc['yahoo']
# Out:
# fisrt      shahab
# last     azarabad
# Name: yahoo, dtype: object

# %% [markdown]
# ### this will help by easier search by some specific data

# %% [markdown]
# in here we search who is using yahoo

# %%
d_df2.loc['yahoo','last']
# Out:
# 'azarabad'

# %%
d_df2.iloc[0]
# Out:
# fisrt      shahab
# last     azarabad
# Name: yahoo, dtype: object

# %%
d_df2.reset_index(inplace=True)
d_df2
# Out:
#    email   fisrt      last
# 0  yahoo  shahab  azarabad
# 1  gmail  sadegh   mirzaei
# 2  gmail  nasrin  ebadpour

# %% [markdown]
# ### Get back to our main dataframe

# %%
df= pd.read_csv('C:/Users/sh.azarabad/Desktop/machine learning dataset/Hotel/Hotel_Reservations.csv',index_col='Booking_ID')
df.head()
# Out:
#             no_of_adults  no_of_children  no_of_weekend_nights  \
# Booking_ID
# INN00001               2               0                     1
# INN00002               2               0                     2
# INN00003               1               0                     2
# INN00004               2               0                     0
# INN00005               2               0                     1
#
#             no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# Booking_ID
# INN00001                    2       Meal Plan 1                           0
# INN00002                    3      Not Selected                           0
# INN00003                    1       Meal Plan 1                           0
# INN00004                    2       Meal Plan 1                           0
# INN00005                    1      Not Selected                           0
#
#            room_type_reserved  lead_time  arrival_year  arrival_month  \
# Booking_ID
# ...

# %% [markdown]
# ### If you want to sort

# %%
df.sort_index(ascending= True)
# Out:
#             no_of_adults  no_of_children  no_of_weekend_nights  \
# Booking_ID
# INN00001               2               0                     1
# INN00002               2               0                     2
# INN00003               1               0                     2
# INN00004               2               0                     0
# INN00005               2               0                     1
# ...                  ...             ...                   ...
# INN36271               3               0                     2
# INN36272               2               0                     1
# INN36273               2               0                     2
# INN36274               2               0                     0
# INN36275               2               0                     1
#
#             no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# Booking_ID
# INN00001                    2       Meal Plan 1                           0
# ...

# %% [markdown]
# # Part4

# %% [markdown]
#   ## Filtering

# %% [markdown]
# ### we want to find people who use gmail

# %%
d_df['email'] == 'gmail'
# Out:
# 0    False
# 1     True
# 2     True
# Name: email, dtype: bool

# %%
filt = (d_df['email'] == 'gmail')
d_df[filt]
# Out:
#     fisrt      last  email
# 1  sadegh   mirzaei  gmail
# 2  nasrin  ebadpour  gmail

# %%
d_df.loc[filt , 'last']
# Out:
# 1     mirzaei
# 2    ebadpour
# Name: last, dtype: object

# %% [markdown]
# & for and , | for or

# %%
filt = (d_df['email'] == 'gmail') & (d_df['fisrt']=='sadegh')
d_df.loc[filt , 'last']
# Out:
# 1    mirzaei
# Name: last, dtype: object

# %%
filt = (d_df['email'] == 'yahoo') | (d_df['fisrt']=='sadegh')
d_df.loc[filt , 'last']
# Out:
# 0    azarabad
# 1     mirzaei
# Name: last, dtype: object

# %% [markdown]
# ### get the opposite

# %%
d_df.loc[~filt , 'last']
# Out:
# 2    ebadpour
# Name: last, dtype: object

# %% [markdown]
# get back to our main data frame

# %%
df
# Out:
#             no_of_adults  no_of_children  no_of_weekend_nights  \
# Booking_ID
# INN00001               2               0                     1
# INN00002               2               0                     2
# INN00003               1               0                     2
# INN00004               2               0                     0
# INN00005               2               0                     1
# ...                  ...             ...                   ...
# INN36271               3               0                     2
# INN36272               2               0                     1
# INN36273               2               0                     2
# INN36274               2               0                     0
# INN36275               2               0                     1
#
#             no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# Booking_ID
# INN00001                    2       Meal Plan 1                           0
# ...

# %%
room6 = (df['room_type_reserved'] == 'Room_Type 6')
df.loc[room6,'type_of_meal_plan']
# Out:
# Booking_ID
# INN00061    Meal Plan 1
# INN00081    Meal Plan 1
# INN00100    Meal Plan 1
# INN00128    Meal Plan 1
# INN00227    Meal Plan 1
#                ...
# INN36099    Meal Plan 1
# INN36222    Meal Plan 1
# INN36228    Meal Plan 1
# INN36250    Meal Plan 1
# INN36270    Meal Plan 1
# Name: type_of_meal_plan, Length: 966, dtype: object

# %%
room_type= ['Room_Type 3','Room_Type 2']
filt2 = df['room_type_reserved'].isin(room_type)

# %%
df.loc[filt2,'room_type_reserved']
# Out:
# Booking_ID
# INN00033    Room_Type 2
# INN00115    Room_Type 2
# INN00289    Room_Type 2
# INN00404    Room_Type 2
# INN00488    Room_Type 2
#                ...
# INN36135    Room_Type 2
# INN36150    Room_Type 2
# INN36163    Room_Type 2
# INN36218    Room_Type 2
# INN36267    Room_Type 2
# Name: room_type_reserved, Length: 699, dtype: object

# %% [markdown]
# ### search in string

# %%
filt=(df['booking_status'].str.contains('Not',na=False))
df.loc[filt,'booking_status']
# Out:
# Booking_ID
# INN00001    Not_Canceled
# INN00002    Not_Canceled
# INN00007    Not_Canceled
# INN00008    Not_Canceled
# INN00009    Not_Canceled
#                 ...
# INN36264    Not_Canceled
# INN36266    Not_Canceled
# INN36271    Not_Canceled
# INN36273    Not_Canceled
# INN36275    Not_Canceled
# Name: booking_status, Length: 24390, dtype: object

# %% [markdown]
# # Part5

# %% [markdown]
# ## Updating

# %%
d_df
# Out:
#     fisrt      last  email
# 0  shahab  azarabad  yahoo
# 1  sadegh   mirzaei  gmail
# 2  nasrin  ebadpour  gmail

# %%
d_df.columns
# Out:
# Index(['fisrt', 'last', 'email'], dtype='object')

# %% [markdown]
# Update columns name

# %%
d_df.columns =['first_name','last_name','email']
d_df.columns
# Out:
# Index(['first_name', 'last_name', 'email'], dtype='object')

# %% [markdown]
# ### Make Columns Uppercase

# %%
d_df.columns = [x.upper() for x in d_df.columns]
d_df
# Out:
#   FIRST_NAME LAST_NAME  EMAIL
# 0     shahab  azarabad  yahoo
# 1     sadegh   mirzaei  gmail
# 2     nasrin  ebadpour  gmail

# %%
d_df.columns = d_df.columns.str.replace('_' , ' ')
d_df
# Out:
#   FIRST NAME LAST NAME  EMAIL
# 0     shahab  azarabad  yahoo
# 1     sadegh   mirzaei  gmail
# 2     nasrin  ebadpour  gmail

# %%
d_df.rename(columns={'FIRST NAME':'first','LAST NAME' : 'last' , 'EMAIL':'email'},inplace=True)

# %% [markdown]
# ## Update data

# %%
d_df.loc[2 , 'last']='Ebadpoor'
d_df
# Out:
#     first      last  email
# 0  shahab  azarabad  yahoo
# 1  sadegh   mirzaei  gmail
# 2  nasrin  Ebadpoor  gmail

# %%
d_df.loc[2 , ['last','email']]=['Ebadpoor','email']
d_df
# Out:
#     first      last  email
# 0  shahab  azarabad  yahoo
# 1  sadegh   mirzaei  gmail
# 2  nasrin  Ebadpoor  email

# %%
d_df.loc[2]=['nasrin' ,'ebadpour' , 'n.ebadpor@gmail.com']
d_df
# Out:
#     first      last                email
# 0  shahab  azarabad                yahoo
# 1  sadegh   mirzaei                gmail
# 2  nasrin  ebadpour  n.ebadpor@gmail.com

# %%
filt = (d_df['first'] == 'shahab')
d_df.loc[filt,'email'] = 'SH.az@yahoo.com'
d_df
# Out:
#     first      last                email
# 0  shahab  azarabad      SH.az@yahoo.com
# 1  sadegh   mirzaei                gmail
# 2  nasrin  ebadpour  n.ebadpor@gmail.com

# %% [markdown]
# ## Update multiple rows

# %%
d_df['email'] = d_df['email'].str.lower()
d_df
# Out:
#     first      last                email
# 0  shahab  azarabad      sh.az@yahoo.com
# 1  sadegh   mirzaei                gmail
# 2  nasrin  ebadpour  n.ebadpor@gmail.com

# %% [markdown]
# ## apply , map , applymap, replace

# %%
d_df['email'].apply(len)
# Out:
# 0    15
# 1     5
# 2    19
# Name: email, dtype: int64

# %%
def update_email(email):
    return email.upper()

# %%
d_df['email'] = d_df['email'].apply(update_email)
d_df
# Out:
#     first      last                email
# 0  shahab  azarabad      SH.AZ@YAHOO.COM
# 1  sadegh   mirzaei                GMAIL
# 2  nasrin  ebadpour  N.EBADPOR@GMAIL.COM

# %%
d_df['email'] = d_df['email'].apply(lambda x : x.lower())
d_df
# Out:
#     first      last                email
# 0  shahab  azarabad      sh.az@yahoo.com
# 1  sadegh   mirzaei                gmail
# 2  nasrin  ebadpour  n.ebadpor@gmail.com

# %%
d_df.apply(len)
# Out:
# first    3
# last     3
# email    3
# dtype: int64

# %%
d_df.apply(len , axis= 'columns')
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
d_df.apply(pd.Series.min)
# Out:
# first      nasrin
# last     azarabad
# email       gmail
# dtype: object

# %%
d_df.apply(lambda x:x.min())
# Out:
# first      nasrin
# last     azarabad
# email       gmail
# dtype: object

# %%
d_df.applymap(len)
# Out:
#    first  last  email
# 0      6     8     15
# 1      6     7      5
# 2      6     8     19

# %%
d_df.applymap(str.upper)
# Out:
#     first      last                email
# 0  SHAHAB  AZARABAD      SH.AZ@YAHOO.COM
# 1  SADEGH   MIRZAEI                GMAIL
# 2  NASRIN  EBADPOUR  N.EBADPOR@GMAIL.COM

# %%
d_df['first'].map({'shahab':'Shahrokh', 'sadegh':'mohammadSadegh'})
# Out:
# 0          Shahrokh
# 1    mohammadSadegh
# 2               NaN
# Name: first, dtype: object

# %%
d_df['first'].replace({'shahab':'Shahrokh', 'sadegh':'mohammadSadegh'})
# Out:
# 0          Shahrokh
# 1    mohammadSadegh
# 2            nasrin
# Name: first, dtype: object

# %% [markdown]
# # Part6

# %% [markdown]
# ## Add and Remove

# %%
d_df['first']+' '+ d_df['last']
# Out:
# 0    shahab azarabad
# 1     sadegh mirzaei
# 2    nasrin ebadpour
# dtype: object

# %%
d_df['full_name'] = d_df['first']+' '+ d_df['last']
d_df
# Out:
#     first      last                email        full_name
# 0  shahab  azarabad      sh.az@yahoo.com  shahab azarabad
# 1  sadegh   mirzaei                gmail   sadegh mirzaei
# 2  nasrin  ebadpour  n.ebadpor@gmail.com  nasrin ebadpour

# %%
d_df.drop(columns = ['first' , 'last'],inplace = True)

# %%
d_df['full_name'].str.split(' ',expand=True)
# Out:
#         0         1
# 0  shahab  azarabad
# 1  sadegh   mirzaei
# 2  nasrin  ebadpour

# %%
d_df[['first','last']]=d_df['full_name'].str.split(' ',expand=True)
d_df
# Out:
#                  email        full_name   first      last
# 0      sh.az@yahoo.com  shahab azarabad  shahab  azarabad
# 1                gmail   sadegh mirzaei  sadegh   mirzaei
# 2  n.ebadpor@gmail.com  nasrin ebadpour  nasrin  ebadpour

# %%
d_df=d_df.append({'first':'Tony','last':'stark'},ignore_index=True)
d_df
# Out:
#                  email        full_name   first      last
# 0      sh.az@yahoo.com  shahab azarabad  shahab  azarabad
# 1                gmail   sadegh mirzaei  sadegh   mirzaei
# 2  n.ebadpor@gmail.com  nasrin ebadpour  nasrin  ebadpour
# 3                  NaN              NaN    Tony     stark

# %%
d_df.drop(index=3 , inplace = True)

# %%
d_df
# Out:
#                  email        full_name   first      last
# 0      sh.az@yahoo.com  shahab azarabad  shahab  azarabad
# 1                gmail   sadegh mirzaei  sadegh   mirzaei
# 2  n.ebadpor@gmail.com  nasrin ebadpour  nasrin  ebadpour
